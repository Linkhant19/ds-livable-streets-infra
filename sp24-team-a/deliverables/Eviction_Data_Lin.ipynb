# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/eviction.csv')
violation_type_column = df['violation_type']
print(violation_type_column)
# Out:
# 0                 Housing Complaints
# 1                Sanitation Requests
# 2                Sanitation Requests
# 3                 Housing Complaints
# 4                Sanitation Requests
#                      ...
# 329093           Sanitation Requests
# 329094           Sanitation Requests
# 329095           Sanitation Requests
# 329096            Housing Complaints
# 329097    Civic Maintenance Requests
# Name: violation_type, Length: 329098, dtype: object

# %%
violation_counts = df['violation_type'].value_counts()

# This is for plotting.
violation_counts.plot(kind='bar')
plt.title('Violation Type Frequencies')
plt.xlabel('Violation Type')
plt.ylabel('Frequency')
plt.xticks(rotation=90) 
plt.show()

# %%
# Here, we are grouping by neighborhood and violation type and counting the occurrences
grouped_data = df.groupby(['neighborhood', 'violation_type']).size().unstack(fill_value=0)

grouped_data.plot(kind='bar', stacked=True, figsize=(10, 7))
plt.title('Violation Types by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Count of Violation Types')
plt.xticks(rotation=90)  
plt.legend(title='Violation Type')
plt.show()

# %%
# trend for Allston

df['year'] = df['date'].str[:4]

neighborhood_data = df[df['neighborhood'] == 'Allston']

trend_data = neighborhood_data.groupby(['year', 'violation_type']).size().unstack(fill_value=0)

trend_data.plot(kind='line', figsize=(10, 6), marker='o')
plt.title('Trend of Violation Types in Allston Over Years')
plt.xlabel('Year')
plt.ylabel('Count of Violation Types')
plt.xticks(rotation=45)
plt.legend(title='Violation Type')
plt.grid(True)
plt.show()

# %%
# trend for Dorchester

df['year'] = df['date'].str[:4]

neighborhood_data = df[df['neighborhood'] == 'Dorchester']

trend_data = neighborhood_data.groupby(['year', 'violation_type']).size().unstack(fill_value=0)

trend_data.plot(kind='line', figsize=(10, 6), marker='o')
plt.title('Trend of Violation Types in Dorchester Over Years')
plt.xlabel('Year')
plt.ylabel('Count of Violation Types')
plt.xticks(rotation=45)
plt.legend(title='Violation Type')
plt.grid(True)
plt.show()

# %% [markdown]
# Here, we can observe that the housing violations have spiked up from 2022 to 2023.

# %%
# trend for South Boston

df['year'] = df['date'].str[:4]

neighborhood_data = df[df['neighborhood'] == 'South Boston']

trend_data = neighborhood_data.groupby(['year', 'violation_type']).size().unstack(fill_value=0)

trend_data.plot(kind='line', figsize=(10, 6), marker='o')
plt.title('Trend of Violation Types in South Boston Over Years')
plt.xlabel('Year')
plt.ylabel('Count of Violation Types')
plt.xticks(rotation=45)
plt.legend(title='Violation Type')
plt.grid(True)
plt.show()

# %% [markdown]
# Here, we can see observe that since 2021, housing complaints have been going down for South Boston.

# %%
# trend for Brighton

df['year'] = df['date'].str[:4]

neighborhood_data = df[df['neighborhood'] == 'Brighton']

trend_data = neighborhood_data.groupby(['year', 'violation_type']).size().unstack(fill_value=0)

trend_data.plot(kind='line', figsize=(10, 6), marker='o')
plt.title('Trend of Violation Types in Brighton Over Years')
plt.xlabel('Year')
plt.ylabel('Count of Violation Types')
plt.xticks(rotation=45)
plt.legend(title='Violation Type')
plt.grid(True)
plt.show()
